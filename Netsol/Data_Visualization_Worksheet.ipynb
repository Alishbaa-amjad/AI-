# %% [markdown]
# # 📊 Data Visualization — Practice Worksheet
# ### Tasks covering Matplotlib, Seaborn, Bokeh & Plotly
#
# ---
#
# > 📌 **Instructions**
# > - Complete **all 9 tasks** in order.
# > - Each task builds on concepts covered in the lecture.
# > - Fill in the `# YOUR CODE HERE` sections only — do not change the task descriptions.
# > - Run each cell after completing it to verify your output.
#
# **Libraries you will need:** `matplotlib`, `seaborn`, `bokeh`, `plotly`

# %% [markdown]
# ## ⚙️ Setup — Run This First
#
# Import all required libraries before starting the tasks.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool, ColumnDataSource
# %matplotlib inline
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f470cbde-f774-48ac-ad3e-72d9b5d36bb7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ---
# ## 📝 Task 1 — Multi-Line Plot with Matplotlib
#
# ### Background
# Line plots are used to show **trends over time**. When comparing multiple series on the same chart you add a legend so readers can distinguish them.
#
# ### 🎯 Your Task
# The table below shows the **monthly revenue** (in $000s) of two products over 6 months.
#
# | Month | Product A | Product B |
# |-------|-----------|-----------|
# | Jan | 15 | 10 |
# | Feb | 18 | 13 |
# | Mar | 14 | 16 |
# | Apr | 22 | 18 |
# | May | 25 | 20 |
# | Jun | 28 | 24 |
#
# Create a **single line chart** that shows **both products** with:
# - Different colors and markers for each line
# - A legend identifying each product
# - Proper axis labels and a descriptive title
# - Grid lines enabled
#
# > 💡 **Hint:** Plot both series with `plt.plot()` twice, passing `label=` each time, then call `plt.legend()`.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in e:\ai\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in e:\ai\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\ai\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\ai\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\ai\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in e:\ai\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in e:\ai\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in e:\ai\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\ai\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in e:\ai\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in e:\ai\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
product_a = [15, 18, 14, 22, 25, 28]
product_b = [10, 13, 16, 18, 20, 24]

# Plot Product A line (choose any color and marker)
plt.plot(months, product_a, marker='^', color='teal')
# Plot Product B line (choose a different color and marker)
plt.plot(months, product_b, marker='^', color='blue')
# Add title, axis labels, legend, and grid
plt.title('sales Over a year')
plt.xlabel('Month')
plt.ylabel('products')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 2 — Grouped Bar Chart with Matplotlib
#
# ### Background
# A **grouped bar chart** places multiple bars side by side for the same category, making it easy to compare values within each group.
#
# ### 🎯 Your Task
# The data below shows **exam scores** for three subjects across two classes.
#
# | Subject | Class A | Class B |
# |---------|---------|---------|
# | Math | 72 | 68 |
# | Science | 85 | 80 |
# | English | 78 | 74 |
# | History | 65 | 70 |
#
# Create a **grouped bar chart** with:
# - Two bars (Class A and Class B) side by side for each subject
# - Different colors for each class
# - Value labels on top of each bar
# - A legend, axis labels, and a title
#
# > 💡 **Hint:** Use `np.arange(len(subjects))` for x-positions, then offset each group with `x - 0.2` and `x + 0.2` and `width=0.4`.
# > To add labels: loop over bars using `bar.get_height()` and `plt.text()`.

# %%
import matplotlib.pyplot as plt
import numpy as np

subjects = ['Math', 'Science', 'English', 'History']
class_a  = [72, 85, 78, 65]
class_b  = [68, 80, 74, 70]

# YOUR CODE HERE
# Create x positions using np.arange
x = np.arange(len(subjects))

# Plot Class A bars (offset left)
plt.bar(x - 0.2, class_a, width=0.4, label='class_a',color='orange')

# Plot Class B bars (offset right)
plt.bar(x + 0.2, class_b, width=0.4, label='class_b', color='red')

# Add value labels above each bar

# Add title, axis labels, legend, and x-tick labels
plt.title('Student Marks Data')
plt.xlabel('Subjects')
plt.ylabel('Class')
plt.xticks(x,subjects)
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 3 — Histogram Analysis with Matplotlib
#
# ### Background
# Histograms reveal the **shape of a distribution** — whether it is symmetric, skewed, or has multiple peaks. The number of bins controls the granularity.
#
# ### 🎯 Your Task
# A teacher recorded the following **test scores** for 20 students:
#
# ```
# scores = [45, 55, 60, 62, 65, 65, 68, 70, 70, 72,
#           75, 75, 78, 80, 82, 85, 88, 90, 92, 95]
# ```
#
# **Part A:** Plot a histogram with **5 bins**.
# **Part B:** Below Part A (use `plt.subplot`), plot the **same data with 10 bins**.
# Both plots should have:
# - A different color each
# - Edge color set to black
# - Axis labels and a title describing the bin count
#
# > 💡 **Hint:** Use `plt.subplot(1, 2, 1)` for the first and `plt.subplot(1, 2, 2)` for the second. Call `plt.tight_layout()` at the end.

# %%
import matplotlib.pyplot as plt

scores = [45, 55, 60, 62, 65, 65, 68, 70, 70, 72,
          75, 75, 78, 80, 82, 85, 88, 90, 92, 95]

plt.figure(figsize=(12, 4))

# YOUR CODE HERE
# Part A: Histogram with 5 bins (subplot 1)
plt.subplot(1, 2, 1)
plt.hist(scores, bins=5, color='purple', edgecolor='black')
plt.title('histrogram with 5 bins')
plt.xlabel('scores')
plt.ylabel('Number of students')
plt.show()

# Part B: Histogram with 10 bins (subplot 2)
plt.figure(figsize=(17, 4))

plt.subplot(1, 2, 2)
plt.hist(scores, bins=10, color='green', edgecolor='black')
plt.xticks(scores)
plt.title('histrogram with 10 bins')
plt.xlabel('scores')
plt.ylabel('Number of students')
plt.show()

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 4 — Dashboard of 4 Plots with Matplotlib Subplots
#
# ### Background
# Real-world reports often present **multiple charts together** in a grid layout. `plt.subplots(rows, cols)` creates this grid and returns an `axes` array.
#
# ### 🎯 Your Task
# Using the data provided, create a **2×2 subplot dashboard** containing:
#
# | Position | Chart | Data |
# |----------|-------|------|
# | Top-left (0,0) | Line plot | `months` vs `sales` |
# | Top-right (0,1) | Bar chart | `cities` vs `population` |
# | Bottom-left (1,0) | Scatter plot | `hours` vs `grades` |
# | Bottom-right (1,1) | Pie chart | `categories` / `expenses` |
#
# Each subplot must have its own title. The figure should have an overall `suptitle` of `"Monthly Dashboard"`.
#
# > 💡 **Hint:** Access each subplot as `axes[row, col]`. For the pie chart use `axes[1,1].pie(...)`.
# > Use `fig.suptitle("Monthly Dashboard", fontsize=14)` for the main title.

# %%
import matplotlib.pyplot as plt

months     = ['Jan','Feb','Mar','Apr','May','Jun']
sales      = [200, 240, 180, 300, 350, 320]

cities     = ['Karachi','Lahore','Islamabad','Peshawar']
population = [16, 13, 2, 4]   # millions

hours      = [1, 2, 3, 4, 5, 6, 7, 8]
grades     = [50, 55, 60, 65, 72, 78, 85, 90]

categories = ['Food', 'Rent', 'Transport', 'Entertainment']
expenses   = [40, 30, 15, 15]

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# YOUR CODE HERE

# Top-left: line plot of sales over months
axes[0,0].plot(months, sales, marker='^', color='teal')
axes[0,0].plot(months, sales, marker='^', color='red')
axes[0,0].set_title('sales Over a year')
axes[0,0].set_xlabel('Month')
axes[0,0].set_ylabel('sales')
axes[0,0].grid(True)

# Top-right: bar chart of city populations
axes[0,1].bar(cities, population, color='teal')
axes[0,1].bar(cities, population, color='red')
axes[0,1].set_title('population in cities')
axes[0,1].set_xlabel('cities')
axes[0,1].set_ylabel('population')
axes[0,1].grid(True)

# Bottom-left: scatter plot of hours vs grades
axes[1,0].scatter(hours, grades, color='green')
axes[1,0].set_title('Study Hours to get good marks')
axes[1,0].set_xlabel('Hours Studied')
axes[1,0].set_ylabel('grades')
axes[1,0].grid(True)

# Bottom-right: pie chart of expenses
axes[1,1].pie(expenses, labels=categories, autopct='%1.0f%%', colors=['red', 'yellow', 'orange', 'green'])
axes[1,1].set_title('different categories')

fig.suptitle("Monthly Dashboard", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 5 — Seaborn EDA on the `tips` Dataset
#
# ### Background
# Seaborn's statistical plots make it very easy to explore relationships in a dataset. The `tips` dataset records restaurant bill information.
#
# ### 🎯 Your Task
# Load the `tips` dataset and create the following **3 plots** (each in its own cell or in subplots):
#
# **Plot 1 — Box Plot:** Distribution of `tip` amounts grouped by `day`, with `sex` as the hue.
#
# **Plot 2 — Violin Plot:** Distribution of `total_bill` grouped by `time` (Lunch / Dinner).
#
# **Plot 3 — Heatmap:** Correlation matrix of all numeric columns in `tips`, with annotations and the `coolwarm` colormap.
#
# Each plot needs a descriptive title.
#
# > 💡 **Hint for heatmap:** Use `tips.corr(numeric_only=True)` to get the correlation matrix, then pass it to `sns.heatmap(..., annot=True, cmap='coolwarm')`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

# YOUR CODE HERE — Plot 1: Box plot (tip by day, hue=sex)
sns.boxplot(x='day', y='tip', hue='sex', data=tips, palette='Set3') 
#agar Set1,Set2,Set3, krty rhy gay male and female ka color change hota rhy ga
plt.title('Distribution of tip amount')
plt.xlabel('day')
plt.ylabel('Tip amount')
plt.show()

# %%
# YOUR CODE HERE — Plot 2: Violin plot (total_bill by time)
sns.violinplot(x='time', y='total_bill', data=tips) 
plt.title('total_bill by time')
plt.xlabel('time')
plt.ylabel('total_bill')
plt.show()

# %%
# YOUR CODE HERE — Plot 3: Correlation heatmap
corr=tips.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap='coolwarm') 
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 6 — Seaborn Scatter Plot with Regression Line
#
# ### Background
# `sns.scatterplot` shows raw data points; adding `sns.regplot` or `sns.lmplot` overlays a **linear regression line** with a confidence band, making trends easier to read.
#
# ### 🎯 Your Task
# Using the `tips` dataset:
#
# 1. Create a **scatter plot** of `total_bill` (x-axis) vs `tip` (y-axis), colored by `smoker` status.
# 2. On a **separate plot**, use `sns.regplot` (or `sns.lmplot`) to show the same relationship with a **regression line** (ignore the smoker grouping here).
#
# Both plots need titles, axis labels, and a legend where applicable.
#
# > 💡 **Hint:** For the regression plot try `sns.regplot(x='total_bill', y='tip', data=tips, scatter_kws={'alpha':0.5})`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

# YOUR CODE HERE — Part 1: Scatter plot colored by smoker status
sns.scatterplot(x='total_bill', y='tip', hue='smoker', data=tips)
plt.title('Scatter plot')
plt.xlabel('total bill')
plt.ylabel('tip')
plt.legend(title='smoker')
plt.grid(True)
plt.show()

# YOUR CODE HERE — Part 2: Regression plot (total_bill vs tip)
sns.regplot(x='total_bill', y='tip', data=tips)
plt.title('Regression plot')
plt.xlabel('total bill')
plt.ylabel('tip')
plt.grid(True)
plt.show()

# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in e:\ai\lib\site-packages (3.8.0)
# Requirement already satisfied: Jinja2>=2.9 in e:\ai\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in e:\ai\lib\site-packages (from bokeh) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in e:\ai\lib\site-packages (from bokeh) (2.7.0)
# Requirement already satisfied: numpy>=1.16 in e:\ai\lib\site-packages (from bokeh) (2.3.5)
# Requirement already satisfied: packaging>=16.8 in e:\ai\lib\site-packages (from bokeh) (25.0)
# Requirement already satisfied: pandas>=1.2 in e:\ai\lib\site-packages (from bokeh) (2.3.3)
# Requirement already satisfied: pillow>=7.1.0 in e:\ai\lib\site-packages (from bokeh) (12.0.0)
# Requirement already satisfied: PyYAML>=3.10 in e:\ai\lib\site-packages (from bokeh) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in e:\ai\lib\site-packages (from bokeh) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in e:\ai\lib\site-packages (from bokeh) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\ai\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\ai\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\ai\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\ai\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\ai\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)

# %% [markdown]
# ---
# ## 📝 Task 7 — Interactive Line Plot with Bokeh
#
# ### Background
# Bokeh creates **interactive, browser-rendered** plots. The `HoverTool` lets users see exact data values when they hover over points.
#
# ### 🎯 Your Task
# Create an **interactive Bokeh line plot** showing website traffic over 7 days:
#
# ```
# days    = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# visitors = [120, 180, 150, 200, 250, 300, 270]
# ```
#
# Requirements:
# - Line width = 2, color of your choice
# - Circle markers on each data point (size = 8)
# - A `HoverTool` that shows the day and visitor count on hover
# - Proper title and axis labels
#
# > 💡 **Hint:** To use HoverTool with plain lists, convert data to a `ColumnDataSource`.
# > `source = ColumnDataSource(data=dict(days=days, visitors=visitors))`
# > Then use `p.line(x='days', y='visitors', source=source)` and
# > `HoverTool(tooltips=[("Day", "@days"), ("Visitors", "@visitors")])`.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool, ColumnDataSource
output_notebook()
days     = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
visitors = [120, 180, 150, 200, 250, 300, 270]
# YOUR CODE HERE
# 1. Create a ColumnDataSource
source=ColumnDataSource(data=dict(days=days,visitors=visitors))
# 2. Create a Bokeh figure with title and axis labels
p=figure(title="Website Traffic over 7 Days",x_range=days, x_axis_label="days",
         y_axis_label="Number of Visitors")
# 3. Add a line renderer
p.line(x='days',y='visitors',source=source,line_width=2,color="blue")
# 4. Add circle markers
p.circle(x='days',y='visitors',source=source,size=8,color="red",legend_label="visitors")
# 5. Add a HoverTool
hover=HoverTool(tooltips=[("Day", "@days"), ("Visitors", "@visitors")])
# 6. Show the plot
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bcababd9-44da-4b78-ae22-0c4d6d7774f9">Loading BokehJS ...</span>
#     </div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="ec54c31c-5544-4ac1-ada1-1ad3ab743d80" data-root-id="p1011" style="display: contents;"></div>

# %% [markdown]
# ---
# ## 📝 Task 8 — Interactive Charts with Plotly Express
#
# ### Background
# Plotly Express (imported as `px`) creates fully interactive charts in one or two lines. Charts support hover info, zoom, and filtering by legend clicks out of the box.
#
# ### 🎯 Your Task
# Use the **built-in `gapminder` dataset** (`px.data.gapminder()`) to create:
#
# **Part A — Animated Scatter Plot:**
# Plot `gdpPercap` (x, log scale) vs `lifeExp` (y), with:
# - Bubble size = `pop`
# - Color = `continent`
# - Animation frame = `year`
# - Title: "GDP vs Life Expectancy Over Time"
# **Part B — Bar Chart (2007 snapshot):**
# Filter for `year == 2007` and `continent == 'Asia'`. Plot a bar chart of `country`
# vs `lifeExp`, sorted descending. Title: "Life Expectancy in Asia (2007)".
# > 💡 **Hint for Part A:** `px.scatter(..., animation_frame='year', log_x=True,
# > size='pop', size_max=60)`
# > 💡 **Hint for Part B:** Use `df.sort_values('lifeExp', ascending=False)`
# > before plotting.

# %%
import plotly.express as px
gapminder = px.data.gapminder()
# YOUR CODE HERE — Part A: Animated scatter plot
f=px.scatter(gapminder,x="gdpPercap",y="lifeExp",animation_frame='year',log_x=True,size='pop',
             color="continent",size_max=60,title="GDP vs Life Expectancy Over Time")
f.show()

# %%
# YOUR CODE HERE — Part B: Bar chart for Asia in 2007
asia_2007=gapminder[(gapminder["year"]==2007) & (gapminder["continent"]==2007)]
asia_2007=asia_2007.sort_values('lifeExp', ascending=False)
f1=px.scatter(asia_2007,x="country",y="lifeExp",title="Life Expectancy in Asia (2007)")
f1.show()

# %% [markdown]
# ---
# ## 📝 Task 9 — Choose Your Own Visualization
#
# ### Background
# Good data visualization starts with choosing the **right chart type** for your data and message. This task tests that judgment.
#
# ### 🎯 Your Task
# Below is a dataset of a fictional **e-commerce store's weekly performance**:
#
# ```python
# data = {
#     'Day':        ['Mon','Tue','Wed','Thu','Fri','Sat','Sun'],
#     'Orders':     [45,   62,   58,   70,   95,   110,  80 ],
#     'Revenue':    [900,  1240, 1160, 1400, 1900, 2200, 1600],
#     'Returns':    [2,    3,    5,    4,    6,    8,    5   ],
#     'Category':   ['Electronics','Clothing','Books','Electronics','Clothing','Books','Electronics']
# }
# ```
#
# **You must create exactly 3 different chart types** using any combination of Matplotlib,
# Seaborn, or Plotly. For each chart:
# 1. Clearly state (in a comment) **which chart type you chose and why** it suits that
# 2. particular relationship
# 3. Include a title, axis labels, and any useful annotations
#
# **Suggested angles to explore** (pick any 3):
# - Trend of `Orders` or `Revenue` over the week
# - Proportion of `Orders` by `Category`
# - Relationship between `Orders` and `Revenue`
# - Comparison of `Returns` vs `Orders` by day
# > 💡 There is no single correct answer here. Focus on making each chart **clear and informative**.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df = pd.DataFrame({
    'Day':      ['Mon','Tue','Wed','Thu','Fri','Sat','Sun'],
    'Orders':   [45,   62,   58,   70,   95,  110,   80 ],
    'Revenue':  [900, 1240, 1160, 1400, 1900, 2200, 1600],
    'Returns':  [2,    3,    5,    4,    6,    8,    5   ],
    'Category': ['Electronics','Clothing','Books','Electronics','Clothing','Books','Electronics']
})

# ── Chart 1 ──────────────────────────────────────────────────────────────
# Chart type chosen:
# Why it suits this data:
# YOUR CODE HERE
plt.figure(figsize=(8,5))
plt.plot(df["Day"],df["Orders"],marker="o")
plt.title("order trend over week")
plt.xlabel("Day")
plt.ylabel("Number of Orders")
plt.grid(True)
plt.show()

# %%
# ── Chart 2 ──────────────────────────────────────────────────────────────
# Chart type chosen:
# Why it suits this data:
# YOUR CODE HERE
category_count=df["Category"].value_counts()
plt.pie(category_count,labels=category_count.index,autopct="%1.0f%%")
plt.title("properties of order by category")
plt.show()

# %%
# ── Chart 3 ──────────────────────────────────────────────────────────────
# Chart type chosen:
# Why it suits this data:
# YOUR CODE HERE
sns.scatterplot(data=df,x="Orders",y="Revenue",hue="Category",s=120)
plt.title("Relationship between order and revenue")
plt.xlabel("Order")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ---
# ## 🤔 Reflection Questions
#
# Answer the following in the code cell below as comments:
#
# 1. What is the main advantage of using **Seaborn** over raw Matplotlib for statistical plots?
# 2. When would you choose **Bokeh** over **Plotly**, and vice versa?
# 3. In Task 3, how does changing the number of bins affect your interpretation of the distribution?
# 4. Why is a **pie chart** generally not recommended when you have more than 5–6 categories?
# 5. What does a **violin plot** show that a **box plot** does not?

# %%
# Q1: Seaborn provides high-level functions that automate statistical calculations (like regression or error bars) in a single 
# line. It also integrates natively with Pandas, automatically handling labels and colors based on your DataFrame structure.

# Q2: Choose Bokeh for large, streaming datasets or when you need granular, low-level control over custom web dashboard elements. 
# Choose Plotly for its "one-liner" ease of use (Plotly Express) and superior support for 3D charts and geographic maps.

# Q3: Too few bins can hide the true shape of the data, such as merging two distinct peaks into one "oversmoothed" curve. 
# Too many bins create a jagged "undersmoothed" plot that emphasizes random noise rather than the actual statistical trend.

# Q4:The human brain struggles to accurately compare the angles and areas of thin slices, making it hard to rank categories 
# that are similar in size.Additionally,more categories lead to cluttered labels and legends that make the chart difficult
# to read at a glance.

# Q5:A violin plot displays the full probability density (the "shape") of the data, which reveals peaks or clusters that a box 
# plot hides. While a box plot only shows summary statistics like the median and quartiles, the violin plot shows exactly where 
# the data is most concentrated.

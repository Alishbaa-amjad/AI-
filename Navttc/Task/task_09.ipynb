# %%
# Program to solve quadratic equation: ax^2 + bx + c = 0
import cmath

# Step 1: Define coefficients
a = float(input('Enter a: '))
b = float(input('Enter b: '))
c = float(input('Enter c: '))

# Step 2: Calculate the discriminant (d = b^2 - 4ac)
d = (b**2) - (4*a*c)

# Step 3: Find two solutions using the quadratic formula
sol1 = (-b - cmath.sqrt(d)) / (2*a)
sol2 = (-b + cmath.sqrt(d)) / (2*a)

# Step 4: Display the results
print(f'The solutions are {sol1} and {sol2}')
# Out:
# Enter a:  3
# Enter b:  4
# Enter c:  5
# The solutions are (-0.6666666666666666-1.1055415967851332j) and (-0.6666666666666666+1.1055415967851332j)

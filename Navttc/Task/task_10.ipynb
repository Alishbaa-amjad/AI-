# %%
# Program to convert kilometers to miles

# Step 1: Taking input from user in kilometers
kilometers = float(input("Enter value in kilometers: "))

# Step 2: Conversion factor
conv_fac = 0.621371

# Step 3: Calculate miles
miles = kilometers * conv_fac

# Step 4: Display the result
print(f"{kilometers} kilometers is equal to {miles:0.2f} miles")
# Out:
# Enter value in kilometers:  44
# 44.0 kilometers is equal to 27.34 miles

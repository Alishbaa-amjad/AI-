# %%
# Program to convert temperature from Celsius to Fahrenheit

# Step 1: Input temperature in Celsius
celsius = float(input("Enter temperature in Celsius: "))

# Step 2: Apply conversion formula
fahrenheit = (celsius * 1.8) + 32

# Step 3: Display the result
print(f"{celsius} degree Celsius is equal to {fahrenheit:0.2f} degree Fahrenheit")
# Out:
# Enter temperature in Celsius:  44
# 44.0 degree Celsius is equal to 111.20 degree Fahrenheit

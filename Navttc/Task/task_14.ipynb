# %%
i = int(input("enter a number:"))

if (i == 10):
    print ("i is 10")
elif (i == 15):
    print ("i is 15")
elif (i == 20):
    print ("i is 20")
else:
    print ("i is not present")
# Out:
# enter a number: 15
# i is 15
